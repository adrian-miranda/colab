# %% [markdown]
# <a href="https://colab.research.google.com/github/adrian-miranda/colab/blob/master/1_R_Clase2_ML(esta_en_la_carp_sem_4).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("ggplot2")
#_instalacion de biblioteca
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
#Estadistica descriptiva
#Medidas de posición (Summary)
#Medidas de tendencia central
#medidas dispersión

# %%
library(ggplot2)
# _cargar la biblioteca de graficos

# %%
data(mpg)
# Viene incluido dentro del paquete ggplot2
# Cuando ejecutas data(mpg), simplemente estás cargando este conjunto de
# datos predefinido en tu entorno de trabajo para que puedas usarlo directamente.

# %%
mpg
# ESTA ES LA BASE O TABLA COMO TAL, ES LA TABLA VISUALMENTE
# se está refiriendo al conjunto de datos mpg que ya has cargado previamente
# con data(mpg). Esto significa que puedes usar mpg directamente en tu código
# para acceder a los datos.
# Out:
#     manufacturer model              displ year cyl trans      drv cty hwy fl
# 1   audi         a4                 1.8   1999 4   auto(l5)   f   18  29  p
# 2   audi         a4                 1.8   1999 4   manual(m5) f   21  29  p
# 3   audi         a4                 2.0   2008 4   manual(m6) f   20  31  p
# 4   audi         a4                 2.0   2008 4   auto(av)   f   21  30  p
# 5   audi         a4                 2.8   1999 6   auto(l5)   f   16  26  p
# 6   audi         a4                 2.8   1999 6   manual(m5) f   18  26  p
# 7   audi         a4                 3.1   2008 6   auto(av)   f   18  27  p
# 8   audi         a4 quattro         1.8   1999 4   manual(m5) 4   18  26  p
# 9   audi         a4 quattro         1.8   1999 4   auto(l5)   4   16  25  p
# 10  audi         a4 quattro         2.0   2008 4   manual(m6) 4   20  28  p
# 11  audi         a4 quattro         2.0   2008 4   auto(s6)   4   19  27  p
# 12  audi         a4 quattro         2.8   1999 6   auto(l5)   4   15  25  p
# 13  audi         a4 quattro         2.8   1999 6   manual(m5) 4   17  25  p
# 14  audi         a4 quattro         3.1   2008 6   auto(s6)   4   17  25  p
# 15  audi         a4 quattro         3.1   2008 6   manual(m6) 4   15  25  p
# 16  audi         a6 quattro         2.8   1999 6   auto(l5)   4   15  24  p
# 17  audi         a6 quattro         3.1   2008 6   auto(s6)   4   17  25  p
# 18  audi         a6 quattro         4.2   2008 8   auto(s6)   4   16  23  p
# 19  chevrolet    c1500 suburban 2wd 5.3   2008 8   auto(l4)   r   14  20  r
# 20  chevrolet    c1500 suburban 2wd 5.3   2008 8   auto(l4)   r   11  15  e
# 21  chevrolet    c1500 suburban 2wd 5.3   2008 8   auto(l4)   r   14  20  r
# 22  chevrolet    c1500 suburban 2wd 5.7   1999 8   auto(l4)   r   13  17  r
# 23  chevrolet    c1500 suburban 2wd 6.0   2008 8   auto(l4)   r   12  17  r
# 24  chevrolet    corvette           5.7   1999 8   manual(m6) r   16  26  p
# 25  chevrolet    corvette           5.7   1999 8   auto(l4)   r   15  23  p
# 26  chevrolet    corvette           6.2   2008 8   manual(m6) r   16  26  p
# 27  chevrolet    corvette           6.2   2008 8   auto(s6)   r   15  25  p
# 28  chevrolet    corvette           7.0   2008 8   manual(m6) r   15  24  p
# 29  chevrolet    k1500 tahoe 4wd    5.3   2008 8   auto(l4)   4   14  19  r
# 30  chevrolet    k1500 tahoe 4wd    5.3   2008 8   auto(l4)   4   11  14  e
# ⋮   ⋮            ⋮                  ⋮     ⋮    ⋮   ⋮          ⋮   ⋮   ⋮   ⋮
# 205 toyota       toyota tacoma 4wd  3.4   1999 6   auto(l4)   4   15  19  r
# 206 toyota       toyota tacoma 4wd  4.0   2008 6   manual(m6) 4   15  18  r
# 207 toyota       toyota tacoma 4wd  4.0   2008 6   auto(l5)   4   16  20  r
# 208 volkswagen   gti                2.0   1999 4   manual(m5) f   21  29  r
# 209 volkswagen   gti                2.0   1999 4   auto(l4)   f   19  26  r
# 210 volkswagen   gti                2.0   2008 4   manual(m6) f   21  29  p
# 211 volkswagen   gti                2.0   2008 4   auto(s6)   f   22  29  p
# 212 volkswagen   gti                2.8   1999 6   manual(m5) f   17  24  r
# 213 volkswagen   jetta              1.9   1999 4   manual(m5) f   33  44  d
# 214 volkswagen   jetta              2.0   1999 4   manual(m5) f   21  29  r
# 215 volkswagen   jetta              2.0   1999 4   auto(l4)   f   19  26  r
# 216 volkswagen   jetta              2.0   2008 4   auto(s6)   f   22  29  p
# 217 volkswagen   jetta              2.0   2008 4   manual(m6) f   21  29  p
# 218 volkswagen   jetta              2.5   2008 5   auto(s6)   f   21  29  r
# 219 volkswagen   jetta              2.5   2008 5   manual(m5) f   21  29  r
# 220 volkswagen   jetta              2.8   1999 6   auto(l4)   f   16  23  r
# 221 volkswagen   jetta              2.8   1999 6   manual(m5) f   17  24  r
# 222 volkswagen   new beetle         1.9   1999 4   manual(m5) f   35  44  d
# 223 volkswagen   new beetle         1.9   1999 4   auto(l4)   f   29  41  d
# 224 volkswagen   new beetle         2.0   1999 4   manual(m5) f   21  29  r
# 225 volkswagen   new beetle         2.0   1999 4   auto(l4)   f   19  26  r
# 226 volkswagen   new beetle         2.5   2008 5   manual(m5) f   20  28  r
# 227 volkswagen   new beetle         2.5   2008 5   auto(s6)   f   20  29  r
# 228 volkswagen   passat             1.8   1999 4   manual(m5) f   21  29  p
# 229 volkswagen   passat             1.8   1999 4   auto(l5)   f   18  29  p
# 230 volkswagen   passat             2.0   2008 4   auto(s6)   f   19  28  p
# 231 volkswagen   passat             2.0   2008 4   manual(m6) f   21  29  p
# 232 volkswagen   passat             2.8   1999 6   auto(l5)   f   16  26  p
# 233 volkswagen   passat             2.8   1999 6   manual(m5) f   18  26  p
# 234 volkswagen   passat             3.6   2008 6   auto(s6)   f   17  26  p
#     class
# 1   compact
# 2   compact
# 3   compact
# 4   compact
# 5   compact
# 6   compact
# 7   compact
# 8   compact
# 9   compact
# 10  compact
# 11  compact
# 12  compact
# 13  compact
# 14  compact
# 15  compact
# 16  midsize
# 17  midsize
# 18  midsize
# 19  suv
# 20  suv
# 21  suv
# 22  suv
# 23  suv
# 24  2seater
# 25  2seater
# 26  2seater
# 27  2seater
# 28  2seater
# 29  suv
# 30  suv
# ⋮   ⋮
# 205 pickup
# 206 pickup
# 207 pickup
# 208 compact
# 209 compact
# 210 compact
# 211 compact
# 212 compact
# 213 compact
# 214 compact
# 215 compact
# 216 compact
# 217 compact
# 218 compact
# 219 compact
# 220 compact
# 221 compact
# 222 subcompact
# 223 subcompact
# 224 subcompact
# 225 subcompact
# 226 subcompact
# 227 subcompact
# 228 midsize
# 229 midsize
# 230 midsize
# 231 midsize
# 232 midsize
# 233 midsize
# 234 midsize

# %%
?mpg
# DOCUMENTACION Y ESTRUCTURA DE LA BBDD

# %%
# summary() para obtener un resumen detallado de los resultados de un modelo estadístico:
# minimo maximo mediana quintiles 1 .25 y 3 .75 y mean , promedio quizas
summary(mpg$cty) #Rendimientos en millas x galon en ciudad
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    9.00   14.00   17.00   16.86   19.00   35.00

# %%
quantile(mpg$cty,probs=c(0.25,0.5,0.75))
#Quintiles
#El [25%, 50%, 75%] de los valores de cty SON MENORES o iguales a X
# Out:
# 25% 50% 75%
#  14  17  19

# %%
mean(mpg$cty)
#mean= media aritmética promedio de todos los valores
# Out:
# [1] 16.85897

# %%
median(mpg$cty)
#median valor del medio en un conjunto de datos
# Out:
# [1] 17

# %%
sqrt(var(mpg$cty)) #Desviación estandar
# Out:
# [1] 4.255946

# %%
sd(mpg$cty)  #Desviación estandar
# Out:
# [1] 4.255946

# %%
sd(mpg$hwy) #millas por galon en carretera
# Out:
# [1] 5.954643

# %%
#Coeficiente de variacion
#Se usa para evaluar dispersión relativa de una distribución de datos, a diferencia de SD, esto mide las dispesion en una misma unidad
#se expresa en %, permite comparar la variabilidad de los conjuntos de datons  qe tienen distintas escalas o unidades
sd(mpg$cty)/mean(mpg$cty)
sd(mpg$hwy)/mean(mpg$hwy)
# Out:
# [1] 0.2524439
# [1] 0.2540358

# %%
#Correlación de variables
#busca cuantificar el nivel de asociación que existe entre 2 variables
#coeficiente de correlación entre dos variables, el mas popular es correlación de pearson
#valores posibles -1 y 1
#1 se dice que es una correlación positiva o directamente proporcional, con pendiente positiva de la gráfica
#-1 negativa e inversamente proporcional
#0 es neutra

# %%
library(dplyr) #libreria de manipulación de tablas

# %%
?datos

# %%
datos<-select(mpg,manufacturer,displ,hwy)  #hwy es millas por galon y displ es cilindrada
datos
datos2 <-select(mpg, year , cyl)
datos2
# Out:
# Error in select(mpg, manufacturer, displ, hwy): could not find function "select"
# Traceback:

# %%
ggplot(datos)+aes(x=displ,y=hwy)+geom_point()+geom_smooth(method = "lm")
ggplot(datos2)+aes(x=year,y=cyl)+geom_point()+geom_smooth(method = "lm")
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# plot without title
# plot without title

# %%
ggplot(datos %>% filter(displ<5))+aes(x=displ,y=hwy)+geom_point()+geom_smooth(method = "auto")
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# plot without title

# %%
cor(select_if(datos, is.numeric))
#cor() calcula la matriz de correlación entre las columnas numéricas seleccionadas
# Out:
# Error in select_if(datos, is.numeric): could not find function "select_if"
# Traceback:
#
# 1. is.data.frame(x)
# 2. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = invokeRestart("eval_error",
#  .             cnd))
#  . }, "could not find function \"select_if\"", base::quote(select_if(datos,
#  .     is.numeric)))

# %%
cor(select_if(datos, is.numeric , method="spearman"))
# Calcula la correlación de rango, es decir,
# mide la relación entre las posiciones (o rangos) de los valores
# Out:
#       displ    hwy
# displ  1.00000 -0.76602
# hwy   -0.76602  1.00000

# %%
cor(select_if(datos, is.numeric , method="kendall"))
# Calcula la correlación de concordancia,
# comparando el número de pares concordantes y discordantes
# Out:
#       displ    hwy
# displ  1.00000 -0.76602
# hwy   -0.76602  1.00000

# %%
install.packages("tidyverse")
#colección de paquetes diseñada para la manipulación y visualización de datos.

#paquete específicamente diseñado para la visualización de matrices de correlación.
install.packages("corrplot")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
x<-rnorm(100) #genera numeros aleatorios con distribución normal o gaussiana
e<-rnorm(100,sd=1)
y<-1+3*x^3+e  #tangente hiperbolica o una logistica (para problemas de clasificación generica)
A<-data.frame(x=x,y=y)
A
# Out:
#     x           y
# 1    0.76510213   2.38108345
# 2    0.34670244   0.24600434
# 3    0.85202743   3.20117799
# 4    1.35370445   8.59116530
# 5    1.02585587   4.45634345
# 6    1.12952037   4.59510251
# 7    0.40064494   1.62177757
# 8   -0.49090642   0.75774902
# 9    0.19095606   0.42228771
# 10   1.98587953  23.95958832
# 11  -0.04862523  -1.06345730
# 12  -0.95457355  -0.43214573
# 13   0.09456415   0.06614016
# 14  -2.08217735 -24.90115457
# 15  -0.17941963   2.64829072
# 16   1.72063040  17.58885879
# 17  -0.54521389   2.80350076
# 18   1.00022727   4.24987193
# 19  -0.95816019  -2.00551437
# 20   0.22836361   1.35059554
# 21   0.45265120   0.82110174
# 22   0.21433262   1.54125599
# 23  -0.36696739   0.85645959
# 24   1.38369567   7.87338541
# 25  -1.24690099  -4.24511546
# 26  -0.09394572  -0.06761239
# 27  -0.61951128  -0.29085719
# 28   0.17608947   0.41914930
# 29  -1.31103435  -6.50864286
# 30  -0.32021699   2.22596486
# ⋮   ⋮           ⋮
# 71   1.07921518   3.07022776
# 72  -0.23394258   0.65153512
# 73  -1.00928579   0.46262828
# 74  -0.17987064   1.74854217
# 75  -0.75748001  -2.07679573
# 76   0.38308370   0.10266620
# 77   1.12461556   5.56479700
# 78   0.69706318   1.13538796
# 79   1.18279574   4.46072210
# 80   0.18490311  -0.04605148
# 81  -1.46101871  -8.73787170
# 82   1.52603157  11.83553688
# 83  -0.44367986   1.22107999
# 84   0.64245475   2.24520099
# 85   0.42740371   0.78529377
# 86  -0.35670352   2.69503642
# 87   0.04819339   1.69751064
# 88  -1.73971247 -15.29352146
# 89   0.60226624   2.79249852
# 90  -0.14511078   0.81377131
# 91  -1.10137842  -2.45363247
# 92  -1.59254619 -10.75415103
# 93  -1.70877487 -15.31658406
# 94  -0.61669141   1.50455913
# 95   1.25178692   6.41870824
# 96  -0.06330002  -1.51442104
# 97  -1.07900827  -1.16554540
# 98  -1.35662832  -6.65026150
# 99  -1.08175172  -4.43692860
# 100 -1.36321252  -6.58301458

# %%
ggplot(A)+aes(x,y)+geom_point()
# Out:
# plot without title

# %%
plot(x,y)
# Out:
# plot without title

# %%
cor(x,y,method="spearman")
# Out:
# [1] 0.8675788

# %%
library(corrplot)
# Out:
# corrplot 0.94 loaded

# %%
corrplot(cor(datos,method="pearson"),method = "circle")
# Out:
# Plot with title “”

# %%
datos
# Out:
#     displ hwy
# 1   1.8   29
# 2   1.8   29
# 3   2.0   31
# 4   2.0   30
# 5   2.8   26
# 6   2.8   26
# 7   3.1   27
# 8   1.8   26
# 9   1.8   25
# 10  2.0   28
# 11  2.0   27
# 12  2.8   25
# 13  2.8   25
# 14  3.1   25
# 15  3.1   25
# 16  2.8   24
# 17  3.1   25
# 18  4.2   23
# 19  5.3   20
# 20  5.3   15
# 21  5.3   20
# 22  5.7   17
# 23  6.0   17
# 24  5.7   26
# 25  5.7   23
# 26  6.2   26
# 27  6.2   25
# 28  7.0   24
# 29  5.3   19
# 30  5.3   14
# ⋮   ⋮     ⋮
# 205 3.4   19
# 206 4.0   18
# 207 4.0   20
# 208 2.0   29
# 209 2.0   26
# 210 2.0   29
# 211 2.0   29
# 212 2.8   24
# 213 1.9   44
# 214 2.0   29
# 215 2.0   26
# 216 2.0   29
# 217 2.0   29
# 218 2.5   29
# 219 2.5   29
# 220 2.8   23
# 221 2.8   24
# 222 1.9   44
# 223 1.9   41
# 224 2.0   29
# 225 2.0   26
# 226 2.5   28
# 227 2.5   29
# 228 1.8   29
# 229 1.8   29
# 230 2.0   28
# 231 2.0   29
# 232 2.8   26
# 233 2.8   26
# 234 3.6   26

# %%
select (datos,displ,hwy)%>%plot()
# Out:
# plot without title

# %% [markdown]
# Tarea: análisis descriptivo, aplicar comandos e interpretar los resultados y sus correlaciones, que entreguen información valiosa, usando los datos de (mtcars)

# %%
data(mtcars)
#mpg	cyl	disp	hp	drat	wt	qsec	vs	am	gear	carb

# %%
mtcars
#mpg	cyl	disp	hp	drat	wt	qsec	vs	am	gear	carb
# Out:
#                     mpg  cyl disp  hp  drat wt    qsec  vs am gear carb
# Mazda RX4           21.0 6   160.0 110 3.90 2.620 16.46 0  1  4    4
# Mazda RX4 Wag       21.0 6   160.0 110 3.90 2.875 17.02 0  1  4    4
# Datsun 710          22.8 4   108.0  93 3.85 2.320 18.61 1  1  4    1
# Hornet 4 Drive      21.4 6   258.0 110 3.08 3.215 19.44 1  0  3    1
# Hornet Sportabout   18.7 8   360.0 175 3.15 3.440 17.02 0  0  3    2
# Valiant             18.1 6   225.0 105 2.76 3.460 20.22 1  0  3    1
# Duster 360          14.3 8   360.0 245 3.21 3.570 15.84 0  0  3    4
# Merc 240D           24.4 4   146.7  62 3.69 3.190 20.00 1  0  4    2
# Merc 230            22.8 4   140.8  95 3.92 3.150 22.90 1  0  4    2
# Merc 280            19.2 6   167.6 123 3.92 3.440 18.30 1  0  4    4
# Merc 280C           17.8 6   167.6 123 3.92 3.440 18.90 1  0  4    4
# Merc 450SE          16.4 8   275.8 180 3.07 4.070 17.40 0  0  3    3
# Merc 450SL          17.3 8   275.8 180 3.07 3.730 17.60 0  0  3    3
# Merc 450SLC         15.2 8   275.8 180 3.07 3.780 18.00 0  0  3    3
# Cadillac Fleetwood  10.4 8   472.0 205 2.93 5.250 17.98 0  0  3    4
# Lincoln Continental 10.4 8   460.0 215 3.00 5.424 17.82 0  0  3    4
# Chrysler Imperial   14.7 8   440.0 230 3.23 5.345 17.42 0  0  3    4
# Fiat 128            32.4 4    78.7  66 4.08 2.200 19.47 1  1  4    1
# Honda Civic         30.4 4    75.7  52 4.93 1.615 18.52 1  1  4    2
# Toyota Corolla      33.9 4    71.1  65 4.22 1.835 19.90 1  1  4    1
# Toyota Corona       21.5 4   120.1  97 3.70 2.465 20.01 1  0  3    1
# Dodge Challenger    15.5 8   318.0 150 2.76 3.520 16.87 0  0  3    2
# AMC Javelin         15.2 8   304.0 150 3.15 3.435 17.30 0  0  3    2
# Camaro Z28          13.3 8   350.0 245 3.73 3.840 15.41 0  0  3    4
# Pontiac Firebird    19.2 8   400.0 175 3.08 3.845 17.05 0  0  3    2
# Fiat X1-9           27.3 4    79.0  66 4.08 1.935 18.90 1  1  4    1
# Porsche 914-2       26.0 4   120.3  91 4.43 2.140 16.70 0  1  5    2
# Lotus Europa        30.4 4    95.1 113 3.77 1.513 16.90 1  1  5    2
# Ford Pantera L      15.8 8   351.0 264 4.22 3.170 14.50 0  1  5    4
# Ferrari Dino        19.7 6   145.0 175 3.62 2.770 15.50 0  1  5    6
# Maserati Bora       15.0 8   301.0 335 3.54 3.570 14.60 0  1  5    8
# Volvo 142E          21.4 4   121.0 109 4.11 2.780 18.60 1  1  4    2

# %%
?mtcars
#[, 1]  ‘mpg’   Miles/(US) gallon
#[, 2]  ‘cyl’   Number of cylinders
#[, 3]  ‘disp’  Displacement (cu.in.)
#[, 4]  ‘hp’    Gross horsepower
#[, 5]  ‘drat’  Rear axle ratio
#[, 6]  ‘wt’    Weight (1000 lbs)
#[, 7]  ‘qsec’  1/4 mile time
#[, 8]  ‘vs’    Engine (0 = V-shaped, 1 = straight)
#[, 9]  ‘am’    Transmission (0 = automatic, 1 = manual)
#[,10]  ‘gear’  Number of forward gears
#[,11]  ‘carb’  Number of carburetors

# %%
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
datosTarea <- select(mtcars, cyl , hp)
datosTarea
# Out:
#                     cyl hp
# Mazda RX4           6   110
# Mazda RX4 Wag       6   110
# Datsun 710          4    93
# Hornet 4 Drive      6   110
# Hornet Sportabout   8   175
# Valiant             6   105
# Duster 360          8   245
# Merc 240D           4    62
# Merc 230            4    95
# Merc 280            6   123
# Merc 280C           6   123
# Merc 450SE          8   180
# Merc 450SL          8   180
# Merc 450SLC         8   180
# Cadillac Fleetwood  8   205
# Lincoln Continental 8   215
# Chrysler Imperial   8   230
# Fiat 128            4    66
# Honda Civic         4    52
# Toyota Corolla      4    65
# Toyota Corona       4    97
# Dodge Challenger    8   150
# AMC Javelin         8   150
# Camaro Z28          8   245
# Pontiac Firebird    8   175
# Fiat X1-9           4    66
# Porsche 914-2       4    91
# Lotus Europa        4   113
# Ford Pantera L      8   264
# Ferrari Dino        6   175
# Maserati Bora       8   335
# Volvo 142E          4   109

# %%
summary(mtcars$cyl)
mean(mtcars$cyl)
sd(mtcars$cyl)/mean(mtcars$cyl) #coef de variacion
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   4.000   4.000   6.000   6.188   8.000   8.000
# [1] 6.1875
# [1] 0.2886338

# %%
ggplot(datosTarea)+aes(x=cyl , y=hp)+geom_point()+geom_smooth(method = "lm")
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %%
cor(select_if(datosTarea , is.numeric))
# Out:
#     cyl       hp
# cyl 1.0000000 0.8324475
# hp  0.8324475 1.0000000
